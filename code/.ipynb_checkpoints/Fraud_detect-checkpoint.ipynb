# %%
import pandas as pd
import numpy as np
import random as rnd

import time

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# machine learning
from sklearn import svm, tree, linear_model, neighbors, naive_bayes, ensemble, discriminant_analysis, gaussian_process
from xgboost import XGBClassifier

from sklearn import model_selection

# %%
train_df = pd.read_json('../input/transactions_data.txt',lines=True)
train_df.head()
# Out:
#    cardCVV            cardCompany  cardDisplayNumber cardExpDate  \
# 0      992  Runolfsson-Runolfsson   5262119058090111       06/20
# 1      527              Fahey LLC   9647953517911559       06/21
# 2      430          Hamill-Hamill   4444700311329356       05/22
# 3      385              Feil-Feil   9569169426519242       02/19
# 4      542    Bechtelar-Bechtelar   3248504556664997       07/18
#
#                 cardName      cardNetwork        cardNumber cardType  \
# 0               Sid Metz             visa  8972768699995084   credit
# 1       Mertie Considine             visa  1502854323418887  prepaid
# 2          Chasity Kozey  americanexpress  1315266292682552   credit
# 3  Montana Aufderhar Jr.             visa  5393441870846185   credit
# 4      Jovan Murazik Jr.  americanexpress   293874280627531    debit
#
#                                             customer   demo    ...      \
# 0  {'cardNumber': 0, 'customerType': None, 'userI...  False    ...
# 1  {'cardNumber': 0, 'customerType': None, 'userI...  False    ...
# 2  {'cardNumber': 0, 'customerType': None, 'userI...  False    ...
# 3  {'cardNumber': 0, 'customerType': None, 'userI...  False    ...
# 4  {'cardNumber': 0, 'customerType': None, 'userI...  False    ...
#
#   products                                           storePOS storeWeb  \
# 0       []                                               None     None
# 1       []                                               None     None
# 2       []                                               None     None
# 3       []  {'POSCode': 0, 'storeName': None, 'storeRiskSc...     None
# 4       []  {'POSCode': 0, 'storeName': None, 'storeRiskSc...     None
#
#    transAmount transChannel transCurrency      transDate  \
# 0  2019.212078       MOBILE         pound  1519108951539
# 1     0.287541       MOBILE           yen  1519108951690
# 2  2569.155177       MOBILE         pound  1519108951792
# 3  1102.480583          POS        dollar  1519108951894
# 4  3589.219480          POS         rupee  1519108952027
#
#        transDescription                               transId webDetails
# 0  Aut velit est quis e  8eef7316-0bfc-45cc-9d30-1cb943082e71       None
# 1  Qui voluptatem quod   42971644-1b00-4f53-a8e9-9d76662c37cb       None
# 2  Qui aliquam vel ut.   0f92b181-76b2-4d55-a968-cb4e1bd88925       None
# 3  Et eveniet facilis v  969550ac-dd81-4374-a5c7-69a51811678f       None
# 4  Similique iure archi  c1472cda-858e-4d39-8fe2-f0e4ba061581       None
#
# [5 rows x 30 columns]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74988 entries, 0 to 74987
# Data columns (total 30 columns):
# cardCVV                74988 non-null int64
# cardCompany            74988 non-null object
# cardDisplayNumber      74988 non-null int64
# cardExpDate            74988 non-null object
# cardName               74988 non-null object
# cardNetwork            74988 non-null object
# cardNumber             74988 non-null int64
# cardType               74988 non-null object
# customer               74988 non-null object
# demo                   74988 non-null bool
# deviceIP               50168 non-null object
# fraud                  74988 non-null bool
# geoIp                  74988 non-null object
# isAccountFlagged       74988 non-null bool
# mobileDetails          25083 non-null object
# paymentCard            74988 non-null object
# posDetails             24820 non-null object
# processingEndTime      74988 non-null int64
# processingStartTime    74988 non-null int64
# productIdList          74988 non-null object
# products               74988 non-null object
# storePOS               24820 non-null object
# storeWeb               25085 non-null object
# transAmount            74988 non-null float64
# transChannel           74988 non-null object
# transCurrency          74988 non-null object
# transDate              74988 non-null int64
# transDescription       74988 non-null object
# transId                74988 non-null object
# webDetails             25085 non-null object
# dtypes: bool(3), float64(1), int64(6), object(20)
# memory usage: 15.7+ MB

# %%
train_df.iloc[0,14]#mobile details
# Out:
# {'appName': 'Redhold',
#  'deviceIP': '072.169.009.234',
#  'deviceId': 23,
#  'deviceName': 'Gavin',
#  'deviceNetwork': 'airtel',
#  'deviceOS': 'ios',
#  'userLat': -36.919486,
#  'userLong': 175.2689}

# %%
train_df.iloc[3,16]#posDetails
# Out:
# {'POSCode': 2832683732227822980,
#  'geoCity': 'FortMill',
#  'geoCountry': 'US',
#  'geoPoBox': 29707,
#  'geoPostalCode': 29707,
#  'geoPostalCodeType': 'Supermarket',
#  'geoState': 'US-SC',
#  'geoStreet1': 'Ewald Falls',
#  'geoStreet2': '753',
#  'lat': 35.00737,
#  'lon': -80.945076}

# %%
train_df.iloc[5,29]#webDetails
# Out:
# {'browser': 'ub',
#  'deviceIP': '006.079.221.173',
#  'deviceMacAddr': '00:b3:92:e2:f7:8d',
#  'deviceOS': 'MacOS',
#  'hostURL': 'www.judson-pagac.net',
#  'network': None}

# %%
import re

def companyNames(name):
    p1 = re.compile('[a-zA-Z]+-[a-zA-Z]+')
    p2 = re.compile('[a-zA-Z]+, [a-zA-Z]+ and [a-zA-Z]+')
    p3 = re.compile('[a-zA-Z]+ Inc')
    if p1.match(name):
        return name.split('-')[0]    
    elif p2.match(name):
        return name.split(',')[0]
    elif p3.match(name):
        return name.split(' ')[0]
    else:
        return name
    
def fraudNames(name):
    if name==True:
        return 1
    else:
        return 0

def getCardExpYear(date):
    return date.split('/')[1]

from googletrans import Translator
translator = Translator()

def transDescriptionNames(name):
    try:
        return translator.translate(name, dest='en').text
    except ValueError:
        return "NA"

# %%
train_df['cardCompany'] = train_df['cardCompany'].apply(companyNames)
train_df['fraud'] = train_df['fraud'].apply(fraudNames)
train_df['cardExpYear'] = train_df['cardExpDate'].apply(getCardExpYear)

# %%
train_df.loc[train_df.query('fraud == 0').sample(frac=.1).index,'fraud'] = 1
train_df.query('fraud == 1')
# Out:
#        cardCVV         cardCompany  cardDisplayNumber cardExpDate  \
# 1          527           Fahey LLC   9647953517911559       06/21
# 17         411             McGlynn    681227962284246       09/22
# 26         552              Harber   4141047807362103       01/22
# 34         209            Emmerich   8876965250324956       11/19
# 38         836     Gutkowski Group   9106732771650231       01/20
# 45         170            Medhurst   3937972729531636       10/22
# 46         915    Wuckert and Sons    331282950210579       10/21
# 51         580             Kovacek   6120109767312604       02/23
# 64         246            Parisian   1217088711396281       06/20
# 67         350           Romaguera   7527134772847768       01/23
# 70         860              Becker   2408109605041197       01/22
# 71         877         Murazik LLC   6544377598590003       03/21
# 73         501                West   6529603276367549       07/21
# 99         749      Stark and Sons   9529572483863151       07/21
# 112        637              Herzog    225617693970715       11/20
# 123        749             Lebsack   1039459892603411       06/18
# 130        858   Cummings and Sons   9098547927508174       11/20
# 132        645               Kuhic   3113197509317980       10/19
{'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74836  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74866  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74869  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74884  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74886  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74897  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74931  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74941  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74947  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74948  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74950  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74952  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74973  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74975  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
#
#                                                 storePOS  \
# 1                                                   None
# 17                                                  None
# 26                                                  None
# 34                                                  None
# 38     {'POSCode': 0, 'storeName': None, 'storeRiskSc...
# 45                                                  None
# 46     {'POSCode': 0, 'storeName': None, 'storeRiskSc...
# 51     {'POSCode': 0, 'storeName': None, 'storeRiskSc...
# 64                                                  None
# 67                                                  None
# 70                                                  None
# 71                                                  None
# 73     {'POSCode': 0, 'storeName': None, 'storeRiskSc...
# 99                                                  None
# 112    {'POSCode': 0, 'storeName': None, 'storeRiskSc...
# 123                                                 None
# 130                                                 None
# 132                                                 None
# 138                                                 None
# 143                                                 None
# 152                                                 None
# 194                                                 None
# 195                                                 None
# 223                                                 None
# 226                                                 None
# 230    {'POSCode': 0, 'storeName': None, 'storeRiskSc...
# 249                                                 None
# 254    {'POSCode': 0, 'storeName': None, 'storeRiskSc...
# 257                                                 None
# 262    {'POSCode': 0, 'storeName': None, 'storeRiskSc...
# ...                                                  ...
# 74706                                               None
# 74717                                               None
# 74718  {'POSCode': 0, 'storeName': None, 'storeRiskSc...
# 74722                                               None
# 74738  {'POSCode': 0, 'storeName': None, 'storeRiskSc...
# 74741                                               None
# 74751                                               None
# 74771                                               None
# 74772                                               None
# 74778                                               None
# 74779                                               None
# 74785  {'POSCode': 0, 'storeName': None, 'storeRiskSc...
# 74801  {'POSCode': 0, 'storeName': None, 'storeRiskSc...
# 74813                                               None
# 74821                                               None
# 74829                                               None
# 74836                                               None
# 74866                                               None
# 74869                                               None
# 74884                                               None
# 74886                                               None
# 74897                                               None
# 74931  {'POSCode': 0, 'storeName': None, 'storeRiskSc...
# 74941  {'POSCode': 0, 'storeName': None, 'storeRiskSc...
# 74947                                               None
# 74948                                               None
# 74950                                               None
# 74952  {'POSCode': 0, 'storeName': None, 'storeRiskSc...
# 74973                                               None
# 74975  {'POSCode': 0, 'storeName': None, 'storeRiskSc...
#
#                                                 storeWeb  transAmount  \
# 1                                                   None     0.287541
# 17     {'storeIP': None, 'storeId': None, 'storeRiskS...  1452.285210
# 26                                                  None  2762.670152
# 34     {'storeIP': None, 'storeId': None, 'storeRiskS...     0.506684
# 38                                                  None  1379.243494
# 45     {'storeIP': None, 'storeId': None, 'storeRiskS...     0.386575
# 46                                                  None  3950.522048
# 51                                                  None  1544.697307
# 64                                                  None  2483.282959
# 67                                                  None  2678.659173
# 70     {'storeIP': None, 'storeId': None, 'storeRiskS...  1221.182956
# 71     {'storeIP': None, 'storeId': None, 'storeRiskS...  3943.230608
# 73                                                  None  1104.023429
# 99     {'storeIP': None, 'storeId': None, 'storeRiskS...  1681.612583
# 112                                                 None  3876.453709
# 123                                                 None  2465.300500
# 130    {'storeIP': None, 'storeId': None, 'storeRiskS...  2426.560314
# 132    {'storeIP': None, 'storeId': None, 'storeRiskS...     0.075344
# 138                                                 None  2365.501587
# 143                                                 None  3284.325281
# 152    {'storeIP': None, 'storeId': None, 'storeRiskS...     0.063136
# 194    {'storeIP': None, 'storeId': None, 'storeRiskS...  2233.549652
# 195    {'storeIP': None, 'storeId': None, 'storeRiskS...  1413.370772
# 223    {'storeIP': None, 'storeId': None, 'storeRiskS...  2459.860937
# 226                                                 None     0.463309
# 230                                                 None  1276.528488
# 249                                                 None  1404.395543
# 254                                                 None     0.702976
# 257    {'storeIP': None, 'storeId': None, 'storeRiskS...  3918.356000
# 262                                                 None     0.205411
# ...                                                  ...          ...
# 74706                                               None  1266.135766
# 74717                                               None     0.990579
# 74718                                               None  1171.563371
# 74722  {'storeIP': None, 'storeId': None, 'storeRiskS...  3883.395272
# 74738                                               None  2479.623318
# 74741                                               None  2731.234887
# 74751  {'storeIP': None, 'storeId': None, 'storeRiskS...  3692.493071
# 74771                                               None  3877.430352
# 249    431bfcf3-e560-42a4-bf9f-9a5257e5e8ec
# 254    8efd4c26-363d-4a83-865f-70762d609dff
# 257    8e570f2d-8e3e-4173-8b87-ed26c7fedd28
# 262    f3394368-e860-47fd-b2f6-2305a83bbf12
# ...                                     ...
# 74706  fba42fd3-6d6e-4f97-b46b-0623361c8f8b
# 74717  3a9932cd-d7ac-40c4-a63d-0b1fccbc865c
# 74718  694a67a2-67f0-4bb2-a5a0-15202e95596f
# 74722  c3583786-8a41-47b2-acde-4fc3c4c644d4
# 74738  b12704ef-b8f9-4d49-b83d-376e97aac73d
# 74741  a4e43b00-9fa7-459f-9d7a-69db7ed6fa0f
# 74751  11f7a29b-369f-4a35-bda4-5ab4ef46b412
# 74771  6f4fcc7d-94e4-44d7-a8d0-60e9ed748c43
# 74772  ca0b1c5d-11c6-41e5-95d6-0f0b856da7c6
# 74778  3681589c-f4ce-4cf5-9382-e592c04dda94
# 74779  8fa2af58-9d41-45e8-a135-9d97f43cb8ec
# 74785  1afbfadf-7950-4e5c-8c14-186e435c3531
# 74801  1a3236ff-bdef-4422-b1a2-5fdee86c2ee3
# 74813  7e91ec5e-15bd-41f0-9522-09ae23d2ecaa
# 74821  414315d7-32a8-4d84-8988-081c6b82725a
# 74829  f9daff86-0850-4c37-b07f-06fba6067c3d
# 74836  fc950930-4877-48bd-b662-db27700ca0e0
# 74866  ee3070bd-cc9c-4edf-a9fa-be88f00f7960
# 74869  6ca8e850-ea86-440d-8c16-4fc59bc3575f
# 74884  c4b7aa87-195f-4d96-a678-8640fd6b6cb6
# 74886  00b5d50d-92ba-413c-89d2-a8633d7f9a6e
# 74897  2049633c-8593-4fac-8634-0323e038e6b9
# 74931  b45148c3-5958-4573-b144-2adf725ecb1f
# 74941  af87b5d5-6b74-49bc-8ddc-76e2c73a6e22
# 74947  a8982da1-d3b8-4551-8346-37f61d5237e5
# 74948  20e5eb38-b184-436f-9ab2-89181e687e7c
# 74950  c9d58219-2524-4bd9-b17e-090c7c1cc471
# 74952  9dc72d76-ea1b-467b-b4d9-a51415a9b47d
# 74973  dfbbc490-28ee-4b33-8a22-fe21dc08d753
# 74975  2fe54ffa-eb68-4368-8335-ee8dd918f52b
#
#                                               webDetails cardExpYear
# 1                                                   None          21
# 17     {'deviceMacAddr': 'b6:47:bc:ea:c2:75', 'device...          22
# 26                                                  None          22
# 34     {'deviceMacAddr': '99:89:a6:cf:9b:e8', 'device...          19
# 38                                                  None          20
# 45     {'deviceMacAddr': '6e:4c:77:14:15:eb', 'device...          22
# 46                                                  None          21
# 51                                                  None          23
# 64                                                  None          20
# 67                                                  None          23
# 70     {'deviceMacAddr': 'c4:69:b8:5b:e8:73', 'device...          22
# 71     {'deviceMacAddr': 'f5:4f:77:8f:c1:89', 'device...          21
# 73                                                  None          21
# 99     {'deviceMacAddr': '83:84:21:6e:d6:bd', 'device...          21
# 112                                                 None          20
# 123                                                 None          18
# 130    {'deviceMacAddr': 'c4:c8:83:3f:da:2a', 'device...          20
# 132    {'deviceMacAddr': 'b6:58:57:47:f5:19', 'device...          19
# 138                                                 None          21
# 143                                                 None          19
# 152    {'deviceMacAddr': '9b:86:00:57:0c:a2', 'device...          20
# 194    {'deviceMacAddr': '56:93:eb:47:23:e6', 'device...          18
# 195    {'deviceMacAddr': '4c:bf:d8:c5:1b:eb', 'device...          18
# 223    {'deviceMacAddr': 'c6:12:5b:52:3e:3b', 'device...          20
# 226                                                 None          21
# 230                                                 None          20
# 249                                                 None          19
# 254                                                 None          22
# 257    {'deviceMacAddr': 'a7:1d:59:cd:1f:36', 'device...          19
# 262                                                 None          23
# ...                                                  ...         ...
# 74706                                               None          21
# 74717                                               None          22
# 74718                                               None          18
# 74722  {'deviceMacAddr': 'd1:de:29:d5:54:53', 'device...          20
# 74738                                               None          19
# 74741                                               None          22
# 74751  {'deviceMacAddr': '12:56:e1:b4:e4:c4', 'device...          19
# 74771                                               None          22
# 74772                                               None          20
# 74778                                               None          20
# 74779  {'deviceMacAddr': '2d:58:13:82:04:bd', 'device...          23
# 74785                                               None          19
# 74801                                               None          19
# 74813  {'deviceMacAddr': '46:95:85:29:1c:c8', 'device...          20
# 74821  {'deviceMacAddr': '39:88:e0:e1:b7:10', 'device...          19
# 74829                                               None          18
# 74836  {'deviceMacAddr': '3d:e6:84:fb:62:17', 'device...          22
# 74866  {'deviceMacAddr': '1a:f3:5c:1e:e4:4d', 'device...          19
# 74869                                               None          22
# 74884                                               None          19
# 74886                                               None          21
# 74897                                               None          20
# 74931                                               None          23
# 74941                                               None          20
# 74947                                               None          20
# 74948                                               None          19
# 74950  {'deviceMacAddr': '88:49:2e:58:6a:d8', 'device...          20
# 74952                                               None          19
# 74973                                               None          22
# 74975                                               None          20
#
# [7499 rows x 31 columns]

# %%
train_df.columns
# Out:
# Index(['cardCVV', 'cardCompany', 'cardDisplayNumber', 'cardExpDate',
#        'cardName', 'cardNetwork', 'cardNumber', 'cardType', 'customer', 'demo',
#        'deviceIP', 'fraud', 'geoIp', 'isAccountFlagged', 'mobileDetails',
#        'paymentCard', 'posDetails', 'processingEndTime', 'processingStartTime',
#        'productIdList', 'products', 'storePOS', 'storeWeb', 'transAmount',
#        'transChannel', 'transCurrency', 'transDate', 'transDescription',
#        'transId', 'webDetails', 'cardExpYear'],
#       dtype='object')

# %%
train_df = train_df.drop(['cardCVV','paymentCard','transDate','isAccountFlagged','cardDisplayNumber','cardExpDate','cardName','cardNumber','customer','demo','deviceIP','geoIp','mobileDetails','posDetails','processingEndTime','processingStartTime','productIdList','products','storePOS','storeWeb','transDescription','transId','webDetails'], axis=1)
train_df.head(10)
# Out:
#      cardCompany      cardNetwork cardType  fraud  transAmount transChannel  \
# 0     Runolfsson             visa   credit      0  2019.212078       MOBILE
# 1      Fahey LLC             visa  prepaid      1     0.287541       MOBILE
# 2         Hamill  americanexpress   credit      0  2569.155177       MOBILE
# 3           Feil             visa   credit      0  1102.480583          POS
# 4      Bechtelar  americanexpress    debit      0  3589.219480          POS
# 5         Parker             visa   credit      0  3360.068744          WEB
# 6         Larson             visa    debit      0  1017.393342          POS
# 7        Ritchie             visa    debit      0  3822.475090       MOBILE
# 8   Zemlak Group  americanexpress  prepaid      0     0.499758          POS
# 9  Funk and Sons  americanexpress  prepaid      0  1000.983918          POS
#
#   transCurrency cardExpYear
# 0         pound          20
# 1           yen          21
# 2         pound          22
# 3        dollar          19
# 4         rupee          18
# 5           yen          21
# 6         rupee          22
# 7         rupee          20
# 8         rupee          22
# 9         pound          18

# %%
train_df['amountBand'] = pd.qcut(train_df['transAmount'], 4)
train_df[['amountBand', 'fraud']].groupby(['amountBand'], as_index=False).mean().sort_values(by='fraud', ascending=True)
# Out:
#              amountBand     fraud
# 0     [1.08e-05, 0.796]  0.099323
# 2  (1812.738, 2925.726]  0.099483
# 3  (2925.726, 4994.472]  0.100123
# 1     (0.796, 1812.738]  0.101083

# %%
train_df.loc[ train_df['transAmount'] <= 0.796, 'transAmount'] = 0
train_df.loc[(train_df['transAmount'] > 0.796) & (train_df['transAmount'] <= 1812.738), 'transAmount'] = 1
train_df.loc[(train_df['transAmount'] > 1812.738) & (train_df['transAmount'] <= 2925.726), 'transAmount']   = 2
train_df.loc[ train_df['transAmount'] > 2925.726, 'transAmount'] = 3
train_df['transAmount'] = train_df['transAmount'].astype(int)
train_df = train_df.drop(['amountBand'], axis=1)
train_df.head(5)
# Out:
#   cardCompany      cardNetwork cardType  fraud  transAmount transChannel  \
# 0  Runolfsson             visa   credit      0            2       MOBILE
# 1   Fahey LLC             visa  prepaid      1            0       MOBILE
# 2      Hamill  americanexpress   credit      0            2       MOBILE
# 3        Feil             visa   credit      0            1          POS
# 4   Bechtelar  americanexpress    debit      0            3          POS
#
#   transCurrency cardExpYear
# 0         pound          20
# 1           yen          21
# 2         pound          22
# 3        dollar          19
# 4         rupee          18

# %%
from sklearn.preprocessing import LabelEncoder
train_df = train_df.apply(LabelEncoder().fit_transform)
train_df.head(5)
# Out:
#    cardCompany  cardNetwork  cardType  fraud  transAmount  transChannel  \
# 0          727            2         0      0            2             0
# 1          210            2         2      1            0             0
# 2          290            0         0      0            2             0
# 3          217            2         0      0            1             1
# 4           51            0         1      0            3             1
#
#    transCurrency  cardExpYear
# 0              1            2
# 1              3            3
# 2              1            4
# 3              0            1
# 4              2            0

# %%
x_full = train_df.drop("fraud", axis=1)
y_full = train_df["fraud"]

x_train, x_test, y_train, y_test = model_selection.train_test_split(x_full, y_full, random_state = 0)

gbrt = tree.DecisionTreeClassifier(max_depth=7)
gbrt.fit(x_train,y_train)   
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
predictions = gbrt.predict(x_test)
print ("Train Accuracy :: ", accuracy_score(y_train, gbrt.predict(x_train)))
print ("Test Accuracy  :: ", accuracy_score(y_test, predictions))
print ("Confusion matrix ", confusion_matrix(y_test, predictions))
# Out:
# Train Accuracy ::  0.8999662168169129
# Test Accuracy  ::  0.9003040486477837
# Confusion matrix  [[16877     4]
#  [ 1865     1]]

# %%
pd.crosstab(y_test, predictions, rownames=['Actual'], colnames=['Predicted'], margins=True)
# Out:
# Predicted      0  1    All
# Actual
# 0          16877  4  16881
# 1           1865  1   1866
# All        18742  5  18747
