# %%
import pandas as pd
import numpy as np
import random as rnd

import time

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# machine learning
from sklearn import svm, tree, linear_model, neighbors, naive_bayes, ensemble, discriminant_analysis, gaussian_process
from xgboost import XGBClassifier

from sklearn import model_selection

# %%
train_df = pd.read_json('../input/transactions_data.txt',lines=True)
train_df.head()
# Out:
#    cardCVV            cardCompany  cardDisplayNumber cardExpDate  \
# 0      992  Runolfsson-Runolfsson   5262119058090111       06/20
# 1      527              Fahey LLC   9647953517911559       06/21
# 2      430          Hamill-Hamill   4444700311329356       05/22
# 3      385              Feil-Feil   9569169426519242       02/19
# 4      542    Bechtelar-Bechtelar   3248504556664997       07/18
#
#                 cardName      cardNetwork        cardNumber cardType  \
# 0               Sid Metz             visa  8972768699995084   credit
# 1       Mertie Considine             visa  1502854323418887  prepaid
# 2          Chasity Kozey  americanexpress  1315266292682552   credit
# 3  Montana Aufderhar Jr.             visa  5393441870846185   credit
# 4      Jovan Murazik Jr.  americanexpress   293874280627531    debit
#
#                                             customer   demo    ...      \
# 0  {'cardNumber': 0, 'customerType': None, 'userI...  False    ...
# 1  {'cardNumber': 0, 'customerType': None, 'userI...  False    ...
# 2  {'cardNumber': 0, 'customerType': None, 'userI...  False    ...
# 3  {'cardNumber': 0, 'customerType': None, 'userI...  False    ...
# 4  {'cardNumber': 0, 'customerType': None, 'userI...  False    ...
#
#   products                                           storePOS storeWeb  \
# 0       []                                               None     None
# 1       []                                               None     None
# 2       []                                               None     None
# 3       []  {'POSCode': 0, 'storeName': None, 'storeRiskSc...     None
# 4       []  {'POSCode': 0, 'storeName': None, 'storeRiskSc...     None
#
#    transAmount transChannel transCurrency      transDate  \
# 0  2019.212078       MOBILE         pound  1519108951539
# 1     0.287541       MOBILE           yen  1519108951690
# 2  2569.155177       MOBILE         pound  1519108951792
# 3  1102.480583          POS        dollar  1519108951894
# 4  3589.219480          POS         rupee  1519108952027
#
#        transDescription                               transId webDetails
# 0  Aut velit est quis e  8eef7316-0bfc-45cc-9d30-1cb943082e71       None
# 1  Qui voluptatem quod   42971644-1b00-4f53-a8e9-9d76662c37cb       None
# 2  Qui aliquam vel ut.   0f92b181-76b2-4d55-a968-cb4e1bd88925       None
# 3  Et eveniet facilis v  969550ac-dd81-4374-a5c7-69a51811678f       None
# 4  Similique iure archi  c1472cda-858e-4d39-8fe2-f0e4ba061581       None
#
# [5 rows x 30 columns]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74988 entries, 0 to 74987
# Data columns (total 30 columns):
# cardCVV                74988 non-null int64
# cardCompany            74988 non-null object
# cardDisplayNumber      74988 non-null int64
# cardExpDate            74988 non-null object
# cardName               74988 non-null object
# cardNetwork            74988 non-null object
# cardNumber             74988 non-null int64
# cardType               74988 non-null object
# customer               74988 non-null object
# demo                   74988 non-null bool
# deviceIP               50168 non-null object
# fraud                  74988 non-null bool
# geoIp                  74988 non-null object
# isAccountFlagged       74988 non-null bool
# mobileDetails          25083 non-null object
# paymentCard            74988 non-null object
# posDetails             24820 non-null object
# processingEndTime      74988 non-null int64
# processingStartTime    74988 non-null int64
# productIdList          74988 non-null object
# products               74988 non-null object
# storePOS               24820 non-null object
# storeWeb               25085 non-null object
# transAmount            74988 non-null float64
# transChannel           74988 non-null object
# transCurrency          74988 non-null object
# transDate              74988 non-null int64
# transDescription       74988 non-null object
# transId                74988 non-null object
# webDetails             25085 non-null object
# dtypes: bool(3), float64(1), int64(6), object(20)
# memory usage: 15.7+ MB

# %%
train_df.iloc[0,14]#mobile details
# Out:
# {'appName': 'Redhold',
#  'deviceIP': '072.169.009.234',
#  'deviceId': 23,
#  'deviceName': 'Gavin',
#  'deviceNetwork': 'airtel',
#  'deviceOS': 'ios',
#  'userLat': -36.919486,
#  'userLong': 175.2689}

# %%
train_df.iloc[3,16]#posDetails
# Out:
# {'POSCode': 2832683732227822980,
#  'geoCity': 'FortMill',
#  'geoCountry': 'US',
#  'geoPoBox': 29707,
#  'geoPostalCode': 29707,
#  'geoPostalCodeType': 'Supermarket',
#  'geoState': 'US-SC',
#  'geoStreet1': 'Ewald Falls',
#  'geoStreet2': '753',
#  'lat': 35.00737,
#  'lon': -80.945076}

# %%
train_df.iloc[5,29]#webDetails
# Out:
# {'browser': 'ub',
#  'deviceIP': '006.079.221.173',
#  'deviceMacAddr': '00:b3:92:e2:f7:8d',
#  'deviceOS': 'MacOS',
#  'hostURL': 'www.judson-pagac.net',
#  'network': None}

# %%
import re

def companyNames(name):
    p1 = re.compile('[a-zA-Z]+-[a-zA-Z]+')
    p2 = re.compile('[a-zA-Z]+, [a-zA-Z]+ and [a-zA-Z]+')
    p3 = re.compile('[a-zA-Z]+ Inc')
    p4 = re.compile('[a-zA-Z]+ Group')
    p5 = re.compile('[a-zA-Z]+ LLC')
    p6 = re.compile('[a-zA-Z]+ and Sons')
    if p1.match(name):
        return name.split('-')[0]    
    elif p2.match(name):
        return name.split(',')[0]
    elif p3.match(name) or p4.match(name) or p5.match(name) or p6.match(name):
        return name.split(' ')[0]
    else:
        return name
    
def fraudNames(name):
    if name==True:
        return 1
    else:
        return 0

def getCardExpYear(date):
    return date.split('/')[1]

# %%
train_df['cardCompany'] = train_df['cardCompany'].apply(companyNames)
train_df['fraud'] = train_df['fraud'].apply(fraudNames)
train_df['cardExpYear'] = train_df['cardExpDate'].apply(getCardExpYear)

# %%
train_df.loc[train_df.query('fraud == 0').sample(frac=.1).index,'fraud'] = 1
train_df.query('fraud == 1')
# Out:
#        cardCVV      cardCompany  cardDisplayNumber cardExpDate  \
# 1          527            Fahey   9647953517911559       06/21
# 10         915          Lockman   1753892011274536       02/19
# 16         216             Ward   4962152404796528       12/21
# 21         430           Hamill   4444700311329356       05/22
# 22         307           Deckow   1047248981367687       07/21
# 32         306          McGlynn   4335229471235399       12/20
# 43         980         Gottlieb    373164810120218       07/19
# 62         925            Mante   7603251372124743       02/19
# 65         378            Koepp   8522949315174117       09/18
# 68         190             Torp    433301608512584       04/18
# 84         125          Trantow   6101423137555614       05/21
# 99         749            Stark   9529572483863151       07/21
# 104        373           Ledner    700825433440851       01/21
# 108        811           Barton   6065868172193743       08/20
{'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 108    {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 109    {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 110    {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 127    {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 162    {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 165    {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 184    {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 189    {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 195    {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 199    {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 212    {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 230    {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 238    {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 243    {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 245    {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 246    {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 256    {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# ...                                                  ...    ...     ...
# 74631  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74632  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74638  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74649  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74662  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74669  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74672  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74678  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74692  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74714  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74730  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74735  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74767  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74783  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74789  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74791  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74795  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74806  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74849  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74866  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74877  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74891  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74910  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74922  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74941  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74942  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74966  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74978  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74979  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
# 74984  {'cardNumber': 0, 'customerType': None, 'userI...  False     ...
#
#                                                 storePOS  \
# 1                                                   None
# 10                                                  None
# 16                                                  None
# 21     {'POSCode': 0, 'storeName': None, 'storeRiskSc...
# 22     {'POSCode': 0, 'storeName': None, 'storeRiskSc...
# 32                                                  None
# 43                                                  None
# 62                                                  None
# 65     {'POSCode': 0, 'storeName': None, 'storeRiskSc...
# 68     {'POSCode': 0, 'storeName': None, 'storeRiskSc...
# 84                                                  None
# 99                                                  None
# 104    {'POSCode': 0, 'storeName': None, 'storeRiskSc...
# 108    {'POSCode': 0, 'storeName': None, 'storeRiskSc...
# 109                                                 None
# 110                                                 None
# 127                                                 None
# 162                                                 None
# 165    {'POSCode': 0, 'storeName': None, 'storeRiskSc...
# 184                                                 None
# 189    {'POSCode': 0, 'storeName': None, 'storeRiskSc...
# 195                                                 None
# 199    {'POSCode': 0, 'storeName': None, 'storeRiskSc...
# 212                                                 None
# 230    {'POSCode': 0, 'storeName': None, 'storeRiskSc...
# 238                                                 None
# 243    {'POSCode': 0, 'storeName': None, 'storeRiskSc...
# 245                                                 None
# 246                                                 None
# 256                                                 None
# ...                                                  ...
# 74631                                               None
# 74632  {'POSCode': 0, 'storeName': None, 'storeRiskSc...
# 74638                                               None
# 74649                                               None
# 74662                                               None
# 74669  {'POSCode': 0, 'storeName': None, 'storeRiskSc...
# 74672  {'POSCode': 0, 'storeName': None, 'storeRiskSc...
# 74678  {'POSCode': 0, 'storeName': None, 'storeRiskSc...
# 74692                                               None
# 74714  {'POSCode': 0, 'storeName': None, 'storeRiskSc...
# 74730                                               None
# 74735                                               None
# 74767  {'POSCode': 0, 'storeName': None, 'storeRiskSc...
# 74783  {'POSCode': 0, 'storeName': None, 'storeRiskSc...
# 74789                                               None
# 74791  {'POSCode': 0, 'storeName': None, 'storeRiskSc...
# 74795                                               None
# 74806                                               None
# 74849                                               None
# 74866                                               None
# 74877                                               None
# 74891                                               None
# 74910  {'POSCode': 0, 'storeName': None, 'storeRiskSc...
# 74922  {'POSCode': 0, 'storeName': None, 'storeRiskSc...
# 74941  {'POSCode': 0, 'storeName': None, 'storeRiskSc...
# 74942  {'POSCode': 0, 'storeName': None, 'storeRiskSc...
# 74966                                               None
# 74978                                               None
# 74979  {'POSCode': 0, 'storeName': None, 'storeRiskSc...
# 74984                                               None
#
#                                                 storeWeb  transAmount  \
# 1                                                   None     0.287541
# 10                                                  None     0.699533
# 16     {'storeIP': None, 'storeId': None, 'storeRiskS...     0.667463
# 21                                                  None  2229.321605
# 22                                                  None     0.715935
# 32                                                  None  3598.445526
# 43                                                  None  1347.842547
# 62                                                  None  3567.089584
# 65                                                  None  3875.204355
# 68                                                  None  2628.193892
# 84                                                  None     0.137068
# 99     {'storeIP': None, 'storeId': None, 'storeRiskS...  1681.612583
# 104                                                 None  3488.183626
# 108                                                 None     0.889014
# 109                                                 None  3073.187038
# 110                                                 None  1294.452639
# 127                                                 None     0.211825
# 162    {'storeIP': None, 'storeId': None, 'storeRiskS...     0.236870
# 165                                                 None  1787.704600
# 184    {'storeIP': None, 'storeId': None, 'storeRiskS...  1590.192377
# 189                                                 None     0.063422
# 195    {'storeIP': None, 'storeId': None, 'storeRiskS...  1413.370772
# 199                                                 None  1904.511931
# 212                                                 None  3820.905434
# 230                                                 None  1276.528488
# 238                                                 None  2613.644044
# 243                                                 None  2739.934779
# 245    {'storeIP': None, 'storeId': None, 'storeRiskS...  3394.565015
# 246    {'storeIP': None, 'storeId': None, 'storeRiskS...     0.931852
# 256    {'storeIP': None, 'storeId': None, 'storeRiskS...     0.015322
# ...                                                  ...          ...
# 74631                                               None  1136.937074
# 74632                                               None  2689.097979
# 74638                                               None  3862.919658
# 74649                                               None     0.989877
# 74662  {'storeIP': None, 'storeId': None, 'storeRiskS...     0.573226
# 74669                                               None  1524.800697
# 74672                                               None  2131.699225
# 74678                                               None     0.166221
# 74692                                               None  1899.002197
# 74714                                               None     0.859688
# 74730                                               None  1513.781087
# 74735                                               None  3273.445804
# 189                                                 None          20
# 195    {'deviceMacAddr': '4c:bf:d8:c5:1b:eb', 'device...          18
# 199                                                 None          19
# 212                                                 None          22
# 230                                                 None          20
# 238                                                 None          21
# 243                                                 None          19
# 245    {'deviceMacAddr': '0d:58:d7:2b:b2:aa', 'device...          20
# 246    {'deviceMacAddr': '0c:74:c8:08:28:e6', 'device...          20
# 256    {'deviceMacAddr': '66:8d:0f:1c:e4:ca', 'device...          21
# ...                                                  ...         ...
# 74631                                               None          22
# 74632                                               None          18
# 74638                                               None          23
# 74649                                               None          22
# 74662  {'deviceMacAddr': '85:34:76:97:f8:66', 'device...          21
# 74669                                               None          18
# 74672                                               None          22
# 74678                                               None          21
# 74692                                               None          21
# 74714                                               None          18
# 74730                                               None          19
# 74735                                               None          21
# 74767                                               None          22
# 74783                                               None          22
# 74789                                               None          20
# 74791                                               None          22
# 74795  {'deviceMacAddr': 'ac:3b:78:70:37:bc', 'device...          19
# 74806  {'deviceMacAddr': 'fd:9f:91:5e:95:ae', 'device...          21
# 74849                                               None          22
# 74866  {'deviceMacAddr': '1a:f3:5c:1e:e4:4d', 'device...          19
# 74877                                               None          19
# 74891  {'deviceMacAddr': 'ed:42:a6:f5:c9:47', 'device...          18
# 74910                                               None          22
# 74922                                               None          20
# 74941                                               None          20
# 74942                                               None          22
# 74966  {'deviceMacAddr': '9a:27:f8:25:2b:5e', 'device...          19
# 74978  {'deviceMacAddr': '19:49:82:0a:f7:f1', 'device...          19
# 74979                                               None          22
# 74984                                               None          20
#
# [7499 rows x 31 columns]

# %%
train_df.columns
# Out:
# Index(['cardCVV', 'cardCompany', 'cardDisplayNumber', 'cardExpDate',
#        'cardName', 'cardNetwork', 'cardNumber', 'cardType', 'customer', 'demo',
#        'deviceIP', 'fraud', 'geoIp', 'isAccountFlagged', 'mobileDetails',
#        'paymentCard', 'posDetails', 'processingEndTime', 'processingStartTime',
#        'productIdList', 'products', 'storePOS', 'storeWeb', 'transAmount',
#        'transChannel', 'transCurrency', 'transDate', 'transDescription',
#        'transId', 'webDetails', 'cardExpYear'],
#       dtype='object')

# %%
train_df = train_df.drop(['cardCVV','paymentCard','transDate','isAccountFlagged','cardDisplayNumber','cardExpDate','cardName','cardNumber','customer','demo','deviceIP','geoIp','mobileDetails','posDetails','processingEndTime','processingStartTime','productIdList','products','storePOS','storeWeb','transDescription','transId','webDetails'], axis=1)
train_df.head(10)
# Out:
#   cardCompany      cardNetwork cardType  fraud  transAmount transChannel  \
# 0  Runolfsson             visa   credit      0  2019.212078       MOBILE
# 1       Fahey             visa  prepaid      1     0.287541       MOBILE
# 2      Hamill  americanexpress   credit      0  2569.155177       MOBILE
# 3        Feil             visa   credit      0  1102.480583          POS
# 4   Bechtelar  americanexpress    debit      0  3589.219480          POS
# 5      Parker             visa   credit      0  3360.068744          WEB
# 6      Larson             visa    debit      0  1017.393342          POS
# 7     Ritchie             visa    debit      0  3822.475090       MOBILE
# 8      Zemlak  americanexpress  prepaid      0     0.499758          POS
# 9        Funk  americanexpress  prepaid      0  1000.983918          POS
#
#   transCurrency cardExpYear
# 0         pound          20
# 1           yen          21
# 2         pound          22
# 3        dollar          19
# 4         rupee          18
# 5           yen          21
# 6         rupee          22
# 7         rupee          20
# 8         rupee          22
# 9         pound          18

# %%
train_df['amountBand'] = pd.qcut(train_df['transAmount'], 4)
train_df[['amountBand', 'fraud']].groupby(['amountBand'], as_index=False).mean().sort_values(by='fraud', ascending=True)
# Out:
#              amountBand     fraud
# 0     [1.08e-05, 0.796]  0.098576
# 3  (2925.726, 4994.472]  0.099163
# 2  (1812.738, 2925.726]  0.101029
# 1     (0.796, 1812.738]  0.101243

# %%
train_df.loc[ train_df['transAmount'] <= 0.796, 'transAmount'] = 0
train_df.loc[(train_df['transAmount'] > 0.796) & (train_df['transAmount'] <= 1812.738), 'transAmount'] = 1
train_df.loc[(train_df['transAmount'] > 1812.738) & (train_df['transAmount'] <= 2925.726), 'transAmount']   = 2
train_df.loc[ train_df['transAmount'] > 2925.726, 'transAmount'] = 3
train_df['transAmount'] = train_df['transAmount'].astype(int)
train_df = train_df.drop(['amountBand'], axis=1)
train_df.head(5)
# Out:
#   cardCompany      cardNetwork cardType  fraud  transAmount transChannel  \
# 0  Runolfsson             visa   credit      0            2       MOBILE
# 1       Fahey             visa  prepaid      1            0       MOBILE
# 2      Hamill  americanexpress   credit      0            2       MOBILE
# 3        Feil             visa   credit      0            1          POS
# 4   Bechtelar  americanexpress    debit      0            3          POS
#
#   transCurrency cardExpYear
# 0         pound          20
# 1           yen          21
# 2         pound          22
# 3        dollar          19
# 4         rupee          18

# %%
from sklearn.preprocessing import LabelEncoder
train_df = train_df.apply(LabelEncoder().fit_transform)
train_df.head(5)
# Out:
#    cardCompany  cardNetwork  cardType  fraud  transAmount  transChannel  \
# 0          377            2         0      0            2             0
# 1          109            2         2      1            0             0
# 2          152            0         0      0            2             0
# 3          113            2         0      0            1             1
# 4           24            0         1      0            3             1
#
#    transCurrency  cardExpYear
# 0              1            2
# 1              3            3
# 2              1            4
# 3              0            1
# 4              2            0

# %%
x_full = train_df.drop("fraud", axis=1)
y_full = train_df["fraud"]

x_train, x_test, y_train, y_test = model_selection.train_test_split(x_full, y_full, random_state = 0)

gbrt = tree.DecisionTreeClassifier(max_depth=7)
gbrt.fit(x_train,y_train)   
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
predictions = gbrt.predict(x_test)
print ("Train Accuracy :: ", accuracy_score(y_train, gbrt.predict(x_train)))
print ("Test Accuracy  :: ", accuracy_score(y_test, predictions))
print ("Confusion matrix ", confusion_matrix(y_test, predictions))
# Out:
# Train Accuracy ::  0.9000906811756547
# Test Accuracy  ::  0.8999839974395903
# Confusion matrix  [[16871     3]
#  [ 1872     1]]

# %%
pd.crosstab(y_test, predictions, rownames=['Actual'], colnames=['Predicted'], margins=True)
# Out:
# Predicted      0  1    All
# Actual
# 0          16871  3  16874
# 1           1872  1   1873
# All        18743  4  18747
